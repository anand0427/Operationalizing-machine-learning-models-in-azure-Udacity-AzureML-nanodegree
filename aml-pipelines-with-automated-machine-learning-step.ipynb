# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.31.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-152528
# aml-quickstarts-152528
# southcentralus
# 9b72f9e6-56c5-4c16-991b-19c652994860

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'automl1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: automl1,
# Workspace: quick-starts-ws-152528)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "com1"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded......................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [90539ee2][32076cb1-8289-441f-a40f-3bbcbe36ce09], (This step will run and generate new outputs)
# Submitted PipelineRun da2dbc5f-4ce8-4903-b2c6-386318e39ac1
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/da2dbc5f-4ce8-4903-b2c6-386318e39ac1?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-152528/workspaces/quick-starts-ws-152528&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: da2dbc5f-4ce8-4903-b2c6-386318e39ac1
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/da2dbc5f-4ce8-4903-b2c6-386318e39ac1?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-152528/workspaces/quick-starts-ws-152528&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: f6d24f2b-c052-4ab2-9eb7-f0f487eb2284
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f6d24f2b-c052-4ab2-9eb7-f0f487eb2284?wsid=/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourcegroups/aml-quickstarts-152528/workspaces/quick-starts-ws-152528&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'f6d24f2b-c052-4ab2-9eb7-f0f487eb2284', 'target': 'com1', 'status': 'Completed', 'startTimeUtc': '2021-07-26T06:31:43.83125Z', 'endTimeUtc': '2021-07-26T07:21:13.400112Z', 'properties': {'ContentSnapshotId': '04b9eaee-290b-4da5-b7d0-685cae680c35', 'StepType': 'AutoMLStep', 'azureml.moduleid': '32076cb1-8289-441f-a40f-3bbcbe36ce09', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '90539ee2', 'azureml.pipelinerunid': 'da2dbc5f-4ce8-4903-b2c6-386318e39ac1', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'com1', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "9b72f9e6-56c5-4c16-991b-19c652994860", "resource_group": "aml-quickstarts-152528", "workspace_name": "quick-starts-ws-152528", "region": "southcentralus", "compute_target": "com1", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "enable_code_generation": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "test_size": 0.0, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["XGBoostClassifier", "KNN", "GradientBoosting", "TensorFlowDNN", "TensorFlowLinearClassifier", "SVM", "DecisionTree", "LogisticRegression", "RandomForest", "SGD", "MultinomialNaiveBayes", "ExtremeRandomTrees", "LightGBM", "AveragedPerceptronClassifier", "LinearSVM", "BernoulliNaiveBayes"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS3_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "save_mlflow": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"1e8cf695-a0e5-4b78-a9d4-74bc5da03bd0\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '04b9eaee-290b-4da5-b7d0-685cae680c35', 'SetupRunId': 'f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_setup', 'SetupRunContainerId': 'dcid.f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_setup', 'ClientSdkVersion': '1.31.0', 'Featuri ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'da2dbc5f-4ce8-4903-b2c6-386318e39ac1', 'status': 'Completed', 'startTimeUtc': '2021-07-26T06:31:25.868413Z', 'endTimeUtc': '2021-07-26T07:21:45.747926Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg152528.blob.core.windows.net/azureml/ExperimentRun/dcid.da2dbc5f-4ce8-4903-b2c6-386318e39ac1/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=e7f%2BkWpbGtEVKgOKkZKQkd%2FVvFpqtuQXbMTEBpwtWIg%3D&st=2021-07-26T06%3A21%3A29Z&se=2021-07-26T14%3A31%3A29Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg152528.blob.core.windows.net/azureml/ExperimentRun/dcid.da2dbc5f-4ce8-4903-b2c6-386318e39ac1/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=dpjNiH%2BSGziOuBJyvEG%2B0fygweZcr87G6wUCfUM3j%2F8%3D&st=2021-07-26T06%3A21%3A29Z&se=2021-07-26T14%3A31%3A29Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg152528.blob.core.windows.net/azureml/ExperimentRun/dcid.da2dbc5f-4ce8-4903-b2c6-386318e39ac1/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=%2FA6MooFSU0qkxYYuek9Tk6OHeiuPtrpaQRHw5N3GoVw%3D&st=2021-07-26T06%3A21%3A29Z&se=2021-07-26T14%3A31%3A29Z&sp=r'}, 'submittedBy': 'ODL_User 152528'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/f6d24f2b-c052-4ab2-9eb7-f0f487eb2284/metrics_data
# Downloaded azureml/f6d24f2b-c052-4ab2-9eb7-f0f487eb2284/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_3  \
# weighted_accuracy                                  [0.8112787415708428]
# log_loss                                           [0.5027512502749918]
# accuracy                                           [0.8045523520485585]
# f1_score_macro                                     [0.6702140489517618]
# precision_score_weighted                           [0.8911693887031371]
# precision_score_micro                              [0.8045523520485585]
# norm_macro_recall                                   [0.554919264161883]
# precision_score_macro                               [0.647248945172567]
# matthews_correlation                               [0.4042555535889998]
# average_precision_score_weighted                   [0.9305374988988925]
# average_precision_score_macro                      [0.7473022044239287]
# recall_score_macro                                 [0.7774596320809415]
# f1_score_micro                                     [0.8045523520485584]
# AUC_macro                                          [0.8810547247646092]
# AUC_weighted                                       [0.8810547247646092]
# average_precision_score_micro                      [0.8516192652693562]
# recall_score_weighted                              [0.8045523520485585]
# f1_score_weighted                                  [0.8335535834351232]
# balanced_accuracy                                  [0.7774596320809415]
# AUC_micro                                          [0.8730478192690908]
# recall_score_micro                                 [0.8045523520485585]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_2  \
# weighted_accuracy                                  [0.9788136708855519]
# log_loss                                          [0.23859163673166994]
# accuracy                                           [0.8968133535660091]
# f1_score_macro                                     [0.5894568502768959]
# precision_score_weighted                           [0.8782347430230257]
# precision_score_micro                              [0.8968133535660091]
# norm_macro_recall                                 [0.13306084872195267]
# precision_score_macro                              [0.7974430641821946]
# matthews_correlation                              [0.28134685555925826]
# average_precision_score_weighted                    [0.932764317012873]
# average_precision_score_macro                      [0.7463627641758177]
# recall_score_macro                                 [0.5665304243609763]
# f1_score_micro                                     [0.8968133535660091]
# AUC_macro                                           [0.904213601261098]
# AUC_weighted                                       [0.9042136012610981]
# average_precision_score_micro                        [0.96967350172107]
# recall_score_weighted                              [0.8968133535660091]
# f1_score_weighted                                  [0.8651182248508218]
# balanced_accuracy                                  [0.5665304243609763]
# AUC_micro                                          [0.9686772389305542]
# recall_score_micro                                 [0.8968133535660091]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_4  \
# weighted_accuracy                                  [0.9843450583187134]
# log_loss                                          [0.25133889926619346]
# accuracy                                           [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
# precision_score_weighted                            [0.788565560086672]
# precision_score_micro                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# precision_score_macro                              [0.4440060698027314]
# matthews_correlation                                              [0.0]
# average_precision_score_weighted                   [0.9302349317739063]
# average_precision_score_macro                      [0.7344617739058603]
# recall_score_macro                                                [0.5]
# f1_score_micro                                     [0.8880121396054628]
# AUC_macro                                          [0.9006246214205136]
# AUC_weighted                                       [0.9006246214205136]
# average_precision_score_micro                      [0.9692113660332309]
# recall_score_weighted                              [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# balanced_accuracy                                                 [0.5]
# AUC_micro                                           [0.967693636148024]
# recall_score_micro                                 [0.8880121396054628]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_26  \
# weighted_accuracy                                   [0.9664052431712199]
# log_loss                                           [0.21081920387721356]
# accuracy                                            [0.9132018209408195]
# f1_score_macro                                      [0.7370044116793406]
# precision_score_weighted                            [0.9026091673555573]
# precision_score_micro                               [0.9132018209408195]
# norm_macro_recall                                   [0.3978154921672252]
# precision_score_macro                                [0.805875541578718]
# matthews_correlation                                [0.4933194281904053]
# average_precision_score_weighted                    [0.9545988986764915]
# average_precision_score_macro                       [0.8213680950458727]
# recall_score_macro                                  [0.6989077460836126]
# f1_score_micro                                      [0.9132018209408195]
# AUC_macro                                           [0.9456540464242646]
# AUC_weighted                                        [0.9456540464242646]
# average_precision_score_micro                       [0.9807522029918585]
# recall_score_weighted                               [0.9132018209408195]
# f1_score_weighted                                   [0.9040554963962859]
# balanced_accuracy                                   [0.6989077460836126]
# AUC_micro                                           [0.9798173072273482]
# recall_score_micro                                  [0.9132018209408195]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_1  \
# weighted_accuracy                                  [0.9537972210153172]
# log_loss                                          [0.18743634958563793]
# accuracy                                           [0.9071320182094081]
# f1_score_macro                                     [0.7416848907681176]
# precision_score_weighted                           [0.8991976076061607]
# precision_score_micro                              [0.9071320182094081]
# norm_macro_recall                                 [0.43834549418631563]
# precision_score_macro                              [0.7723958081530135]
# matthews_correlation                                [0.488678780261868]
# average_precision_score_weighted                   [0.9505970434373063]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_macro                                 [0.7191727470931578]
# f1_score_micro                                     [0.9071320182094081]
# AUC_macro                                          [0.9392346349984347]
# AUC_weighted                                       [0.9392346349984347]
# average_precision_score_micro                      [0.9791945367231853]
# recall_score_weighted                              [0.9071320182094081]
# f1_score_weighted                                  [0.9021127651963996]
# balanced_accuracy                                  [0.7191727470931578]
# AUC_micro                                          [0.9781770788959222]
# recall_score_micro                                 [0.9071320182094081]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_17  \
# weighted_accuracy                                    [0.743111146165332]
# log_loss                                            [0.5720236036201856]
# accuracy                                            [0.7417298937784522]
# f1_score_macro                                      [0.6118533166837136]
# precision_score_weighted                            [0.8785126923420239]
# precision_score_micro                               [0.7417298937784522]
# norm_macro_recall                                   [0.4723329017295641]
# precision_score_macro                               [0.6098847231200173]
# matthews_correlation                                [0.3221868095593842]
# average_precision_score_weighted                    [0.9084748225925151]
# average_precision_score_macro                       [0.7036967393962631]
# recall_score_macro                                   [0.736166450864782]
# f1_score_micro                                      [0.7417298937784522]
# AUC_macro                                           [0.8139412648398527]
# AUC_weighted                                        [0.8139412648398529]
# average_precision_score_micro                       [0.7830644029677017]
# recall_score_weighted                               [0.7417298937784522]
# f1_score_weighted                                   [0.7860896270883551]
# balanced_accuracy                                    [0.736166450864782]
# AUC_micro                                           [0.8170235400581651]
# recall_score_micro                                  [0.7417298937784522]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_10  \
# weighted_accuracy                                   [0.7314908635529398]
# log_loss                                           [0.49127652879906636]
# accuracy                                            [0.7511380880121397]
# f1_score_macro                                      [0.6474398120166145]
# precision_score_weighted                            [0.9115376497347745]
# precision_score_micro                               [0.7511380880121397]
# norm_macro_recall                                   [0.6605473402649269]
# precision_score_macro                               [0.6452118839394645]
# matthews_correlation                                [0.4379938897086866]
# average_precision_score_weighted                    [0.9297402186831993]
# average_precision_score_macro                       [0.7362910844000551]
# recall_score_macro                                  [0.8302736701324634]
# f1_score_micro                                      [0.7511380880121397]
# AUC_macro                                           [0.8945145569022335]
# AUC_weighted                                        [0.8945145569022334]
# average_precision_score_micro                        [0.867810481910966]
# recall_score_weighted                               [0.7511380880121397]
# f1_score_weighted                                   [0.7958206132032725]
# balanced_accuracy                                   [0.8302736701324634]
# AUC_micro                                           [0.8605651179766096]
# recall_score_micro                                  [0.7511380880121397]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_27  \
# weighted_accuracy                                   [0.9846964181190824]
# log_loss                                           [0.24253315987995216]
# accuracy                                             [0.898937784522003]
# f1_score_macro                                      [0.5698974677991973]
# precision_score_weighted                            [0.8999527846711556]
# precision_score_micro                                [0.898937784522003]
# norm_macro_recall                                  [0.10703403001220724]
# precision_score_macro                               [0.9039456391040519]
# matthews_correlation                               [0.29406097891139277]
# average_precision_score_weighted                    [0.9541037625598804]
# average_precision_score_macro                       [0.8202184227553316]
# recall_score_macro                                  [0.5535170150061036]
# f1_score_micro                                      [0.8989377845220029]
# AUC_macro                                           [0.9436182844398506]
# AUC_weighted                                        [0.9436182844398506]
# average_precision_score_micro                        [0.977698114713341]
# recall_score_weighted                                [0.898937784522003]
# f1_score_weighted                                   [0.8618322665015619]
# balanced_accuracy                                   [0.5535170150061036]
# AUC_micro                                           [0.9765082055167046]
# recall_score_micro                                   [0.898937784522003]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_0  \
# weighted_accuracy                                  [0.9514937218005303]
# log_loss                                          [0.17775706110025447]
# accuracy                                           [0.9116843702579667]
# f1_score_macro                                     [0.7653697272147331]
# precision_score_weighted                           [0.9072720074188747]
# precision_score_micro                              [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
# precision_score_macro                              [0.7819118765348991]
# matthews_correlation                               [0.5323740218566827]
# average_precision_score_weighted                   [0.9531771295804466]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_macro                                 [0.7513392683482543]
# f1_score_micro                                     [0.9116843702579667]
# AUC_macro                                          [0.9450464668693166]
# AUC_weighted                                       [0.9450464668693167]
# average_precision_score_micro                      [0.9806603102489483]
# recall_score_weighted                              [0.9116843702579667]
# f1_score_weighted                                  [0.9091539479147899]
# balanced_accuracy                                  [0.7513392683482543]
# AUC_micro                                           [0.979695082216353]
# recall_score_micro                                 [0.9116843702579667]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_5  ...  \
# weighted_accuracy                                  [0.9760040571939254]  ...
# log_loss                                          [0.22778498162422559]  ...
# accuracy                                           [0.8998482549317147]  ...
# f1_score_macro                                     [0.6263741021433107]  ...
# precision_score_weighted                           [0.8819647608160599]  ...
# precision_score_micro                              [0.8998482549317147]  ...
# norm_macro_recall                                  [0.1862120193314032]  ...
# precision_score_macro                              [0.7946974049883324]  ...
# matthews_correlation                               [0.3312889943073923]  ...
# average_precision_score_weighted                   [0.9336760493890374]  ...
# average_precision_score_macro                      [0.7463002221976248]  ...
# recall_score_macro                                 [0.5931060096657016]  ...
# f1_score_micro                                     [0.8998482549317147]  ...
# AUC_macro                                          [0.9096276352373913]  ...
# AUC_weighted                                       [0.9096276352373913]  ...
# average_precision_score_micro                      [0.9708682078338069]  ...
# recall_score_weighted                              [0.8998482549317147]  ...
# f1_score_weighted                                  [0.8744313595679113]  ...
# balanced_accuracy                                  [0.5931060096657016]  ...
# AUC_micro                                          [0.9698516858900113]  ...
# recall_score_micro                                 [0.8998482549317147]  ...
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_12  \
# weighted_accuracy                                   [0.7625018151481834]
# log_loss                                            [0.5851372073616878]
# accuracy                                            [0.7626707132018209]
# f1_score_macro                                      [0.6349482547378849]
# precision_score_weighted                            [0.8870069816175273]
# precision_score_micro                               [0.7626707132018209]
# norm_macro_recall                                   [0.5267020100139486]
# precision_score_macro                               [0.6255531671940393]
# matthews_correlation                                [0.3636732201433529]
# average_precision_score_weighted                    [0.9221531280206502]
# average_precision_score_macro                       [0.7182837920976786]
# recall_score_macro                                  [0.7633510050069743]
# f1_score_micro                                      [0.7626707132018209]
# AUC_macro                                           [0.8661588375965783]
# AUC_weighted                                        [0.8661588375965784]
# average_precision_score_micro                       [0.8369225675918331]
# recall_score_weighted                               [0.7626707132018209]
# f1_score_weighted                                   [0.8025143533999087]
# balanced_accuracy                                   [0.7633510050069743]
# AUC_micro                                            [0.845128384617333]
# recall_score_micro                                  [0.7626707132018209]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_14  \
# weighted_accuracy                                   [0.9830053841060509]
# log_loss                                           [0.25679670091273193]
# accuracy                                            [0.8910470409711685]
# f1_score_macro                                      [0.5119644328410365]
# precision_score_weighted                            [0.8736838613642759]
# precision_score_micro                               [0.8910470409711685]
# norm_macro_recall                                  [0.04130985260638664]
# precision_score_macro                               [0.8097103019192845]
# matthews_correlation                               [0.15996303899942102]
# average_precision_score_weighted                    [0.9286020856798359]
# average_precision_score_macro                       [0.7394678665486895]
# recall_score_macro                                  [0.5206549263031933]
# f1_score_micro                                      [0.8910470409711685]
# AUC_macro                                           [0.8895112874573721]
# AUC_weighted                                        [0.8895112874573722]
# average_precision_score_micro                         [0.96565269989949]
# recall_score_weighted                               [0.8910470409711685]
# f1_score_weighted                                   [0.8457503243660872]
# balanced_accuracy                                   [0.5206549263031933]
# AUC_micro                                           [0.9655306126678348]
# recall_score_micro                                  [0.8910470409711685]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_15  \
# weighted_accuracy                                   [0.9843450583187134]
# log_loss                                           [0.24899070316528485]
# accuracy                                            [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# precision_score_weighted                             [0.788565560086672]
# precision_score_micro                               [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# precision_score_macro                               [0.4440060698027314]
# matthews_correlation                                               [0.0]
# average_precision_score_weighted                    [0.9192319572355939]
# average_precision_score_macro                        [0.696787339771323]
# recall_score_macro                                                 [0.5]
# f1_score_micro                                      [0.8880121396054628]
# AUC_macro                                           [0.8878612829190493]
# AUC_weighted                                        [0.8878612829190494]
# average_precision_score_micro                       [0.9644309007730516]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# balanced_accuracy                                                  [0.5]
# AUC_micro                                           [0.9651550954336018]
# recall_score_micro                                  [0.8880121396054628]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_19  \
# weighted_accuracy                                   [0.9596285749796182]
# log_loss                                           [0.20678955773307725]
# accuracy                                            [0.9025796661608497]
# f1_score_macro                                      [0.7052632370927009]
# precision_score_weighted                            [0.8890546332831104]
# precision_score_micro                               [0.9025796661608497]
# norm_macro_recall                                   [0.3455932884687698]
# precision_score_macro                               [0.7646535215263494]
# matthews_correlation                                [0.4276972780112856]
# average_precision_score_weighted                    [0.9437150575561564]
# average_precision_score_macro                       [0.7810523962199729]
# recall_score_macro                                  [0.6727966442343849]
# f1_score_micro                                      [0.9025796661608497]
# AUC_macro                                           [0.9285931939975585]
# AUC_weighted                                        [0.9285931939975586]
# average_precision_score_micro                       [0.9757189583187845]
# recall_score_weighted                               [0.9025796661608497]
# f1_score_weighted                                    [0.892406452644354]
# balanced_accuracy                                   [0.6727966442343849]
# AUC_micro                                           [0.9746105401802059]
# recall_score_micro                                  [0.9025796661608497]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_21  \
# weighted_accuracy                                   [0.9514453178489745]
# log_loss                                            [0.2130060589655579]
# accuracy                                            [0.9071320182094081]
# f1_score_macro                                      [0.7471349636754323]
# precision_score_weighted                            [0.9006281342295325]
# precision_score_micro                               [0.9071320182094081]
# norm_macro_recall                                  [0.45729160299121796]
# precision_score_macro                               [0.7707028894127967]
# matthews_correlation                                [0.4975744330930443]
# average_precision_score_weighted                    [0.9494361104382961]
# average_precision_score_macro                       [0.8027890370983095]
# recall_score_macro                                   [0.728645801495609]
# f1_score_micro                                      [0.9071320182094081]
# AUC_macro                                           [0.9365996291541863]
# AUC_weighted                                        [0.9365996291541863]
# average_precision_score_micro                       [0.9783388981244616]
# recall_score_weighted                               [0.9071320182094081]
# f1_score_weighted                                   [0.9032251843711121]
# balanced_accuracy                                    [0.728645801495609]
# AUC_micro                                           [0.9773042799477758]
# recall_score_micro                                  [0.9071320182094081]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_16  \
# weighted_accuracy                                   [0.7410108055785728]
# log_loss                                            [0.5485665187717614]
# accuracy                                            [0.7414264036418816]
# f1_score_macro                                      [0.6140357920230709]
# precision_score_weighted                            [0.8809226163222835]
# precision_score_micro                               [0.7414264036418816]
# norm_macro_recall                                  [0.48620071983358226]
# precision_score_macro                               [0.6123293815152145]
# matthews_correlation                               [0.33049849062033076]
# average_precision_score_weighted                     [0.903477655930332]
# average_precision_score_macro                       [0.6875519830179475]
# recall_score_macro                                  [0.7431003599167911]
# f1_score_micro                                      [0.7414264036418817]
# AUC_macro                                           [0.8156417466430304]
# AUC_weighted                                        [0.8156417466430304]
# average_precision_score_micro                       [0.7465927668683687]
# recall_score_weighted                               [0.7414264036418816]
# f1_score_weighted                                   [0.7861106963597319]
# balanced_accuracy                                   [0.7431003599167911]
# AUC_micro                                           [0.8040412543951958]
# recall_score_micro                                  [0.7414264036418816]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_20  \
# weighted_accuracy                                   [0.9821778030055749]
# log_loss                                           [0.22923370640917518]
# accuracy                                            [0.8998482549317147]
# f1_score_macro                                       [0.593012549294383]
# precision_score_weighted                            [0.8904507721146121]
# precision_score_micro                               [0.8998482549317147]
# norm_macro_recall                                   [0.1364784837185351]
# precision_score_macro                               [0.8509287925696595]
# matthews_correlation                                [0.3094971066200246]
# average_precision_score_weighted                    [0.9528629085612494]
# average_precision_score_macro                       [0.8172913885914492]
# recall_score_macro                                  [0.5682392418592676]
# f1_score_micro                                      [0.8998482549317147]
# AUC_macro                                           [0.9403502288611405]
# AUC_weighted                                        [0.9403502288611404]
# average_precision_score_micro                       [0.9770786013335764]
# recall_score_weighted                               [0.8998482549317147]
# f1_score_weighted                                   [0.8672449503131379]
# balanced_accuracy                                   [0.5682392418592676]
# AUC_micro                                           [0.9761176749616031]
# recall_score_micro                                  [0.8998482549317147]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_18  \
# weighted_accuracy                                   [0.7056904076360051]
# log_loss                                            [0.5898513789613781]
# accuracy                                            [0.7116843702579666]
# f1_score_macro                                      [0.5930609564201792]
# precision_score_weighted                            [0.8800894131070234]
# precision_score_micro                               [0.7116843702579666]
# norm_macro_recall                                  [0.47165400567197735]
# precision_score_macro                               [0.6033466788107265]
# matthews_correlation                               [0.31223028371371786]
# average_precision_score_weighted                    [0.9071549193412809]
# average_precision_score_macro                       [0.6682033913829998]
# recall_score_macro                                  [0.7358270028359887]
# f1_score_micro                                      [0.7116843702579667]
# AUC_macro                                           [0.8334027974592801]
# AUC_weighted                                          [0.83340279745928]
# average_precision_score_micro                       [0.8137610441254878]
# recall_score_weighted                               [0.7116843702579666]
# f1_score_weighted                                   [0.7635612763657791]
# balanced_accuracy                                   [0.7358270028359887]
# AUC_micro                                           [0.8062161595833113]
# recall_score_micro                                  [0.7116843702579666]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_7  \
# weighted_accuracy                                  [0.9843450583187134]
# log_loss                                            [0.285205318568202]
# accuracy                                           [0.8880121396054628]
# f1_score_macro                                     [0.4703423886834914]
# precision_score_weighted                            [0.788565560086672]
# precision_score_micro                              [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# precision_score_macro                              [0.4440060698027314]
# matthews_correlation                                              [0.0]
# average_precision_score_weighted                   [0.9080092714022133]
# average_precision_score_macro                      [0.7010115936027815]
# recall_score_macro                                                [0.5]
# f1_score_micro                                     [0.8880121396054628]
# AUC_macro                                          [0.8220935746609688]
# AUC_weighted                                       [0.8220935746609688]
# average_precision_score_micro                      [0.9484200167896714]
# recall_score_weighted                              [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# balanced_accuracy                                                 [0.5]
# AUC_micro                                          [0.9520743481754902]
# recall_score_micro                                 [0.8880121396054628]
#
#                                  f6d24f2b-c052-4ab2-9eb7-f0f487eb2284_9
# weighted_accuracy                                  [0.7344068279694819]
# log_loss                                           [0.5523683933769831]
# accuracy                                           [0.7341426403641882]
# f1_score_macro                                     [0.6060239266737861]
# precision_score_weighted                            [0.877784234354459]
# precision_score_micro                              [0.7341426403641882]
# norm_macro_recall                                 [0.46615707783872096]
# precision_score_macro                              [0.6069202551264926]
# matthews_correlation                              [0.31572657060037346]
# average_precision_score_weighted                   [0.9133088284124091]
# average_precision_score_macro                      [0.7090973695730232]
# recall_score_macro                                 [0.7330785389193605]
# f1_score_micro                                     [0.7341426403641882]
# AUC_macro                                          [0.8298869864980263]
# AUC_weighted                                       [0.8298869864980263]
# average_precision_score_micro                      [0.7873959113595954]
# recall_score_weighted                              [0.7341426403641882]
# f1_score_weighted                                  [0.7803717451444399]
# balanced_accuracy                                  [0.7330785389193605]
# AUC_micro                                           [0.820976188228359]
# recall_score_micro                                 [0.7341426403641882]
#
# [21 rows x 24 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/f6d24f2b-c052-4ab2-9eb7-f0f487eb2284/model_data
# Downloaded azureml/f6d24f2b-c052-4ab2-9eb7-f0f487eb2284/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=False, is_onnx_compatible=False, observer=None, task='classification', working_dir='/m...
# ), random_state=0, reg_alpha=1.1458333333333335, reg_lambda=1.3541666666666667, subsample=0.6, tree_method='auto'))], verbose=False)), ('11', Pipeline(memory=None, steps=[('maxabsscaler', MaxAbsScaler(copy=True)), ('randomforestclassifier', RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced', criterion='gini', max_depth=None, max_features=0.2, max_leaf_nodes=None, max_samples=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=0.06157894736842105, min_samples_split=0.10368421052631578, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1, oob_score=True, random_state=None, verbose=0, warm_start=False))], verbose=False))], flatten_transform=None, weights=[0.4666666666666667, 0.26666666666666666, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=False,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('0', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(min_data_in_leaf=20, n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals=None,
#           dataset_y_std=None,
#           dataset_uid=None,
#           subsamplin...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None))],
#                verbose=False)), ('20', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(boosting_type='gbdt', colsample_bytree=0.3966666666666666, learning_rate=0.1, max_bin=240, max_depth=10, min_child_weight=7, min_data_in_leaf=1e-05, min_split_gain=0.10526315789473684, n_estimators=10, n_jobs=1, num_leaves=155, problem_info=ProblemInf...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None, reg_alpha=0.42105263157894735, reg_lambda=0.10526315789473684, subsample=0.99))],
#                verbose=False)), ('1', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals=None,
#           dataset_y_std=None,
#           dataset_uid=None,
#           subsampling=False,
#           task='classifi...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, tree_method='auto'))],
#                verbose=False)), ('21', Pipeline(memory=None,
#                steps=[('truncatedsvdwrapper',
#                        TruncatedSVDWrapper(n_components=0.7521052631578947,
#                                            random_state=None)),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.3, gamma=0, grow_policy='lossguide', max_bin=1023, max_depth=9, max_leaves=0, n_estimators=25, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0.10416666666666667, reg_lambda=0.20833333333333334, subsample=0.5, tree_method='hist'))],
#                verbose=False)), ('13', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.7, eta=0.001, gamma=0, max_depth=5, max_leaves=0, n_estimators=10, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_feature...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.1458333333333335, reg_lambda=1.3541666666666667, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('11', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('randomforestclassifier',
#                        RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight='balanced',
#                                               criterion='gini', max_depth=None,
#                                               max_features=0.2, max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=0.06157894736842105,
#                                               min_samples_split=0.10368421052631578,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=1,
#                                               oob_score=True, random_state=None,
#                                               verbose=0, warm_start=False))],
#                verbose=False))],
#       weights=[0.4666666666666667, 0.26666666666666666, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667, 0.06666666666666667],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_2f16873e_ede2_11eb_8edd_4f4305a35afc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f16873e_ede2_11eb_8edd_4f4305a35afclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow0_col0" class="data row0 col0" >28821</td>
#                         <td id="T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow0_col1" class="data row0 col1" >437</td>
#             </tr>
#             <tr>
#                         <th id="T_2f16873e_ede2_11eb_8edd_4f4305a35afclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow1_col0" class="data row1 col0" >1749</td>
#                         <td id="T_2f16873e_ede2_11eb_8edd_4f4305a35afcrow1_col1" class="data row1 col1" >1943</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 4770e795-6f0a-4474-9a76-d375ac2209db,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/9b72f9e6-56c5-4c16-991b-19c652994860/resourceGroups/aml-quickstarts-152528/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-152528/PipelineRuns/PipelineSubmit/4770e795-6f0a-4474-9a76-d375ac2209db)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  203d932d-4ab6-48b2-9a30-247d79a16c6b

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
